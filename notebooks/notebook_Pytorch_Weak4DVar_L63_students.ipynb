# %% [markdown]
# <a href="https://colab.research.google.com/github/CIA-Oceanix/DLOA2023/blob/main/notebooks/notebook_Pytorch_Weak4DVar_L63_students.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Notebook for the implementation of model-based inversion scheme**: Application to the Data Assimilation of Lorenz-63 dynamics given noisy and partial observations.
#
# We consider model-based formulation based on the following variational minimization
# $$\arg \min_x \| x - y\|^2_\Omega + \lambda \|x-\Phi(x)\|^2 $$
#
# The notebook addresses two approaches which differ in the considered prior $\Phi$
# *   *Weak-Constrained 4DVar formulation* with the true ODE-based prior: Pytorch implementation of the gradient descent. You need to code the computation of the gradient of tha variational cost using automatic differentiation tool.
# *   *Exploration of a pretrained plug-and-play prior*: Pytorch gradient descent with a PCA-based prior. You need to compute the loss for such a PCA-based prior.
#
# *Possible extensions*: (i) evaluation of the reconstruction performance depending on the considered observation setting (i.e., sampling and noise), (ii) intercomparison of different types of plug-and-play

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import tensorflow.keras as keras

import time
import copy
import torch
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.nn.functional as F

from sklearn import decomposition
from sklearn.feature_extraction import image

# %%
# !pip install torchviz
import torchviz
# Out:
# Collecting torchviz
#   Downloading torchviz-0.0.2.tar.gz (4.9 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torchviz) (1.10.0+cu111)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.7/dist-packages (from torchviz) (0.10.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torchviz) (3.10.0.2)
# Building wheels for collected packages: torchviz
#   Building wheel for torchviz (setup.py) ... done
#   Created wheel for torchviz: filename=torchviz-0.0.2-py3-none-any.whl size=4151 sha256=c5002f8069a283a176624f6026fcb25ab4f2e0774a80d2032f5cf1317bc859c3
#   Stored in directory: /root/.cache/pip/wheels/04/38/f5/dc4f85c3909051823df49901e72015d2d750bd26b086480ec2
# Successfully built torchviz
# Installing collected packages: torchviz
# Successfully installed torchviz-0.0.2

# %% [markdown]
# # L63 Data simulation

# %%
#os.chdir('/content/drive/My Drive/Colab Notebooks/AnDA')
from scipy.integrate import odeint
from scipy.integrate import solve_ivp
#from AnDA_codes.AnDA_dynamical_models import AnDA_Lorenz_63, AnDA_Lorenz_96

def AnDA_Lorenz_63(S,t,sigma,rho,beta):
    """ Lorenz-63 dynamical model. """
    x_1 = sigma*(S[1]-S[0]);
    x_2 = S[0]*(rho-S[2])-S[1];
    x_3 = S[0]*S[1] - beta*S[2];
    dS  = np.array([x_1,x_2,x_3]);
    return dS

class GD:
    model = 'Lorenz_63'
    class parameters:
        sigma = 10.0
        rho = 28.0
        beta = 8.0/3
    dt_integration = 0.01 # integration time
    dt_states = 1 # number of integeration times between consecutive states (for xt and catalog)
    dt_obs = 8 # number of integration times between consecutive observations (for yo)
    var_obs = np.array([0,1,2]) # indices of the observed variables
    nb_loop_train = 10**2 # size of the catalog
    nb_loop_test = 10000 # size of the true state and noisy observations
    sigma2_catalog = 0.0 # variance of the model error to generate the catalog
    sigma2_obs = 2.0 # variance of the observation error to generate observation

GD = GD()
y0 = np.array([8.0,0.0,30.0])
tt = np.arange(GD.dt_integration,GD.nb_loop_test*GD.dt_integration+0.000001,GD.dt_integration)
#S = odeint(AnDA_Lorenz_63,x0,np.arange(0,5+0.000001,GD.dt_integration),args=(GD.parameters.sigma,GD.parameters.rho,GD.parameters.beta));
S = solve_ivp(fun=lambda t,y: AnDA_Lorenz_63(y,t,GD.parameters.sigma,GD.parameters.rho,GD.parameters.beta),t_span=[0.,5+0.000001],y0=y0,first_step=GD.dt_integration,t_eval=np.arange(0,5+0.000001,GD.dt_integration),method='RK45')

y0 = S.y[:,-1];
S = solve_ivp(fun=lambda t,y: AnDA_Lorenz_63(y,t,GD.parameters.sigma,GD.parameters.rho,GD.parameters.beta),t_span=[0.01,GD.nb_loop_test+0.000001],y0=y0,first_step=GD.dt_integration,t_eval=tt,method='RK45')
S = S.y.transpose()

print(S.shape)
plt.figure(1)
for jj in range(0,3):
  plt.subplot(131+jj)
  plt.plot(S[:,jj])

class time_series:
  values = 0.
  time   = 0.

xt = time_series()
xt.values = S
xt.time   = tt
# Out:
# (10000, 3)

# %%
####################################################
## Generation of training and test dataset
## Extraction of time series of dT time steps
NbTraining = 10000
NbTest     = 2000#256
time_step = 1
dT        = 200
sigNoise  = np.sqrt(2.0)
rateMissingData = (1-1./8.)#0.75#0.95

xt = time_series()
xt.values = S
xt.time   = tt
# extract subsequences
dataTrainingNoNaN = image.extract_patches_2d(xt.values[0:7500:time_step,:],(dT,3),max_patches=NbTraining)
dataTestNoNaN     = image.extract_patches_2d(xt.values[8000::time_step,:],(dT,3),max_patches=NbTest)

# create missing data
flagTypeMissData = 1
if flagTypeMissData == 0:
    print('..... Observation pattern: Random sampling of osberved L63 components')
    indRand         = np.random.permutation(dataTrainingNoNaN.shape[0]*dataTrainingNoNaN.shape[1]*dataTrainingNoNaN.shape[2])
    indRand         = indRand[0:int(rateMissingData*len(indRand))]
    dataTraining    = np.copy(dataTrainingNoNaN).reshape((dataTrainingNoNaN.shape[0]*dataTrainingNoNaN.shape[1]*dataTrainingNoNaN.shape[2],1))
    dataTraining[indRand] = float('nan')
    dataTraining    = np.reshape(dataTraining,(dataTrainingNoNaN.shape[0],dataTrainingNoNaN.shape[1],dataTrainingNoNaN.shape[2]))

    indRand         = np.random.permutation(dataTestNoNaN.shape[0]*dataTestNoNaN.shape[1]*dataTestNoNaN.shape[2])
    indRand         = indRand[0:int(rateMissingData*len(indRand))]
    dataTest        = np.copy(dataTestNoNaN).reshape((dataTestNoNaN.shape[0]*dataTestNoNaN.shape[1]*dataTestNoNaN.shape[2],1))
    dataTest[indRand] = float('nan')
    dataTest          = np.reshape(dataTest,(dataTestNoNaN.shape[0],dataTestNoNaN.shape[1],dataTestNoNaN.shape[2]))

    genSuffixObs    = '_ObsRnd_%02d_%02d'%(100*rateMissingData,10*sigNoise**2)
elif flagTypeMissData == 2:
    print('..... Observation pattern: Only the first L63 component is osberved')
    time_step_obs   = int(1./(1.-rateMissingData))
    dataTraining    = np.zeros((dataTrainingNoNaN.shape))
    dataTraining[:] = float('nan')
    dataTraining[:,::time_step_obs,0] = dataTrainingNoNaN[:,::time_step_obs,0]

    dataTest    = np.zeros((dataTestNoNaN.shape))
    dataTest[:] = float('nan')
    dataTest[:,::time_step_obs,0] = dataTestNoNaN[:,::time_step_obs,0]

    genSuffixObs    = '_ObsDim0_%02d_%02d'%(100*rateMissingData,10*sigNoise**2)

else:
    print('..... Observation pattern: All  L63 components osberved')
    time_step_obs   = int(1./(1.-rateMissingData))
    dataTraining    = np.zeros((dataTrainingNoNaN.shape))
    dataTraining[:] = float('nan')
    dataTraining[:,::time_step_obs,:] = dataTrainingNoNaN[:,::time_step_obs,:]

    dataTest    = np.zeros((dataTestNoNaN.shape))
    dataTest[:] = float('nan')
    dataTest[:,::time_step_obs,:] = dataTestNoNaN[:,::time_step_obs,:]

    genSuffixObs    = '_ObsSub_%02d_%02d'%(100*rateMissingData,10*sigNoise**2)

# set to NaN patch boundaries
dataTraining[:,0:10,:] =  float('nan')
dataTest[:,0:10,:]     =  float('nan')
dataTraining[:,dT-10:dT,:] =  float('nan')
dataTest[:,dT-10:dT,:]     =  float('nan')

# mask for NaN
maskTraining = (dataTraining == dataTraining).astype('float')
maskTest     = ( dataTest    ==  dataTest   ).astype('float')

dataTraining = np.nan_to_num(dataTraining)
dataTest     = np.nan_to_num(dataTest)

# Permutation to have channel as #1 component
dataTraining      = np.moveaxis(dataTraining,-1,1)
maskTraining      = np.moveaxis(maskTraining,-1,1)
dataTrainingNoNaN = np.moveaxis(dataTrainingNoNaN,-1,1)

dataTest      = np.moveaxis(dataTest,-1,1)
maskTest      = np.moveaxis(maskTest,-1,1)
dataTestNoNaN = np.moveaxis(dataTestNoNaN,-1,1)

# set to NaN patch boundaries
#dataTraining[:,0:5,:] =  dataTrainingNoNaN[:,0:5,:]
#dataTest[:,0:5,:]     =  dataTestNoNaN[:,0:5,:]

############################################
## raw data
X_train         = dataTrainingNoNaN
X_train_missing = dataTraining
mask_train      = maskTraining

X_test         = dataTestNoNaN
X_test_missing = dataTest
mask_test      = maskTest

############################################
## normalized data
meanTr          = np.mean(X_train_missing[:]) / np.mean(mask_train)
stdTr           = np.sqrt( np.mean( (X_train_missing-meanTr)**2 ) / np.mean(mask_train) )

if flagTypeMissData == 2:
    meanTr          = np.mean(X_train[:])
    stdTr           = np.sqrt( np.mean( (X_train-meanTr)**2 ) )

x_train_missing = ( X_train_missing - meanTr ) / stdTr
x_test_missing  = ( X_test_missing - meanTr ) / stdTr

# scale wrt std

x_train = (X_train - meanTr) / stdTr
x_test  = (X_test - meanTr) / stdTr

print('.... MeanTr = %.3f --- StdTr = %.3f '%(meanTr,stdTr))

# Generate noisy observsation
X_train_obs = X_train_missing + sigNoise * maskTraining * np.random.randn(X_train_missing.shape[0],X_train_missing.shape[1],X_train_missing.shape[2])
X_test_obs  = X_test_missing  + sigNoise * maskTest * np.random.randn(X_test_missing.shape[0],X_test_missing.shape[1],X_test_missing.shape[2])

x_train_obs = (X_train_obs - meanTr) / stdTr
x_test_obs  = (X_test_obs - meanTr) / stdTr

print('..... Training dataset: %dx%dx%d'%(x_train.shape[0],x_train.shape[1],x_train.shape[2]))
print('..... Test dataset    : %dx%dx%d'%(x_test.shape[0],x_test.shape[1],x_test.shape[2]))
# Out:
# ..... Observation pattern: All  L63 components osberved
# .... MeanTr = 8.431 --- StdTr = 27.612
# ..... Training dataset: 7301x3x200
# ..... Test dataset    : 1801x3x200

# %%
# Visualisation
plt.figure(1)
for jj in range(0,3):
  indjj = 131+jj
  plt.subplot(indjj)
  plt.plot(X_train[20,jj,:],'b-')
  plt.plot(X_train_obs[20,jj,:],'k.')

# %%
# Initial interpolation (linear interpolation or zeros) for missing data

import scipy

mx_train = np.sum( np.sum( X_train , axis = 2 ) , axis = 0 ) / (X_train.shape[0]*X_train.shape[2])

flagInit = 1

if flagInit == 0:
  X_train_Init = mask_train * X_train_obs + (1. - mask_train) * (np.zeros(X_train_missing.shape) + meanTr)
  X_test_Init  = mask_test * X_test_obs + (1. - mask_test) * (np.zeros(X_test_missing.shape) + meanTr)
else:
  X_train_Init = np.zeros(X_train.shape)
  for ii in range(0,X_train.shape[0]):
    # Initial linear interpolation for each component
    XInit = np.zeros((X_train.shape[1],X_train.shape[2]))

    for kk in range(0,3):
      indt  = np.where( mask_train[ii,kk,:] == 1.0 )[0]
      indt_ = np.where( mask_train[ii,kk,:] == 0.0 )[0]

      if len(indt) > 1:
        indt_[ np.where( indt_ < np.min(indt)) ] = np.min(indt)
        indt_[ np.where( indt_ > np.max(indt)) ] = np.max(indt)
        fkk = scipy.interpolate.interp1d(indt, X_train_obs[ii,kk,indt])
        XInit[kk,indt]  = X_train_obs[ii,kk,indt]
        XInit[kk,indt_] = fkk(indt_)
      else:
        XInit[kk,:] = XInit[kk,:] + mx_train[kk]

    X_train_Init[ii,:,:] = XInit

  X_test_Init = np.zeros(X_test.shape)
  for ii in range(0,X_test.shape[0]):
    # Initial linear interpolation for each component
    XInit = np.zeros((X_test.shape[1],X_test.shape[2]))

    for kk in range(0,3):
      indt  = np.where( mask_test[ii,kk,:] == 1.0 )[0]
      indt_ = np.where( mask_test[ii,kk,:] == 0.0 )[0]

      if len(indt) > 1:
        indt_[ np.where( indt_ < np.min(indt)) ] = np.min(indt)
        indt_[ np.where( indt_ > np.max(indt)) ] = np.max(indt)
        fkk = scipy.interpolate.interp1d(indt, X_test_obs[ii,kk,indt])
        XInit[kk,indt]  = X_test_obs[ii,kk,indt]
        XInit[kk,indt_] = fkk(indt_)
      else:
        XInit[kk,:] = XInit[kk,:] + mx_train[kk]

    X_test_Init[ii,:,:] = XInit


x_train_Init = ( X_train_Init - meanTr ) / stdTr
x_test_Init = ( X_test_Init - meanTr ) / stdTr


if 1*1:
  plt.figure()
  plt.subplot(1,2,1)
  plt.plot(X_train_Init[20,0,:],'b-')
  plt.plot(X_train[20,0,:],'m-')
  #plt.plot(XInit[:,0],'r-')
  plt.plot(X_train_obs[20,0,:],'k.')
  plt.subplot(1,2,2)
  plt.plot(X_test_Init[20,0,:],'b-')
  plt.plot(X_test[20,0,:],'m-')
  #plt.plot(XInit[:,0],'r-')
  plt.plot(X_test_obs[20,0,:],'k.')

# %% [markdown]
# # Explicit Euler ODE scheme in Pytorch

# %%
# define forward model (Euler)
class ODE_L63(torch.nn.Module):
    def __init__(self,sigma,rho,beta):
        super(ODE_L63, self).__init__()
        self.sigma = sigma
        self.rho   = rho
        self.beta  = beta

    def forward(self, x):
      x_1 = (self.sigma*(x[:,1]-x[:,0])).view(-1,1)
      x_2 = (x[:,0]*(self.rho-x[:,2])-x[:,1]).view(-1,1)
      x_3 = (x[:,0]*x[:,1] - self.beta*x[:,2]).view(-1,1)

      return torch.cat((x_1,x_2,x_3),dim=1)

# %%
ii = 10

# create torch tensors for observations and hidden states
XGT_torch  = torch.Tensor( X_train[ii,:,:].squeeze().transpose() )
YObs_torch = torch.Tensor( X_train_obs[ii,:,:].squeeze().transpose() )
M_torch    = torch.Tensor( mask_train[ii,:,:].squeeze().transpose() )

# Initialisation
X_torch    = torch.Tensor( X_train_Init[ii,:,:].squeeze().transpose() )

# %%
# check model simulation through an Euler integration scheme
ode_L63 = ODE_L63(10.,28.,8./3)

x0 = XGT_torch[0,:]
dt = 0.01

Xsim = []
for nn in range(0,100):
  if nn == 0:
    xt = x0
  xnew = xt + dt * ode_L63(xt.view(-1,3))
  if nn == 0:
    Xsim = xnew
  else:
    Xsim = torch.cat((Xsim,xnew),axis=0)
    xt   = xnew

plt.figure()
plt.plot(Xsim.cpu().detach().numpy()[:,1],'r-')
plt.plot(XGT_torch.cpu().detach().numpy()[0:100,1],'b-')

# %% [markdown]
# # (Weak-constrained) 4DVar DA  Pytorch

# %%
# 4DVAR assimilation
device  = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# assignment to GPU
ode_L63 = ODE_L63(10.,28.,8./3)
ode_L63 = ode_L63.to(device)

# assimilation loop
t0    = 0
dt    = 0.01
dT    = X_torch.size(0)
NIter = 20000
alpha_obs = 0.01
alpha_dyn = 1.
delta = 0.2

X_torch = torch.autograd.Variable(X_torch, requires_grad=True)
for iter in range(0,NIter):

  # compute losses
  with torch.set_grad_enabled(True):
    # dynamical loss
    x_pred   = X_torch[t0:t0+dT-1,:] + dt * ode_L63(X_torch[t0:t0+dT-1,:])
    loss_dyn = torch.sum((X_torch[t0+1:t0+dT,:] - x_pred)**2 )

    # observation loss
    loss_obs = torch.sum((X_torch - YObs_torch)**2 * M_torch )

    # overall loss
    loss = alpha_obs * loss_obs + alpha_dyn * loss_dyn

    if( np.mod(iter,100) == 0 ):
      print(".... iter %d: loss %.3f dyn_loss %.3f obs_loss %.3f"%(iter,loss,loss_dyn,loss_obs))

    # compute gradient w.r.t. X and update X
    loss.backward()
    X_torch = X_torch - delta * X_torch.grad.data

    #grad_X  = torch.autograd.grad(loss,X_torch,create_graph=True)
    #X_torch = X_torch - delta * grad_X[0]

    X_torch = torch.autograd.Variable(X_torch, requires_grad=True)
# Out:
# /tmp/ipython-input-3001266260.py:33: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   print(".... iter %d: loss %.3f dyn_loss %.3f obs_loss %.3f"%(iter,loss,loss_dyn,loss_obs))
# .... iter 0: loss 1035.752 dyn_loss 1035.752 obs_loss 0.000
# .... iter 100: loss 32.528 dyn_loss 29.088 obs_loss 344.066
# .... iter 200: loss 19.842 dyn_loss 15.791 obs_loss 405.189
# .... iter 300: loss 14.395 dyn_loss 10.027 obs_loss 436.804
# .... iter 400: loss 11.557 dyn_loss 7.057 obs_loss 450.029
# .... iter 500: loss 9.864 dyn_loss 5.344 obs_loss 452.042
# .... iter 600: loss 8.744 dyn_loss 4.271 obs_loss 447.317
# .... iter 700: loss 7.940 dyn_loss 3.554 obs_loss 438.605
# .... iter 800: loss 7.326 dyn_loss 3.049 obs_loss 427.607
# .... iter 900: loss 6.834 dyn_loss 2.680 obs_loss 415.380
# .... iter 1000: loss 6.426 dyn_loss 2.400 obs_loss 402.585
# .... iter 1100: loss 6.078 dyn_loss 2.182 obs_loss 389.634
# .... iter 1200: loss 5.775 dyn_loss 2.007 obs_loss 376.783
# .... iter 1300: loss 5.507 dyn_loss 1.865 obs_loss 364.189
# .... iter 1400: loss 5.266 dyn_loss 1.746 obs_loss 351.947
# .... iter 1500: loss 5.047 dyn_loss 1.646 obs_loss 340.111
# .... iter 1600: loss 4.847 dyn_loss 1.560 obs_loss 328.709
# .... iter 1700: loss 4.662 dyn_loss 1.484 obs_loss 317.753
# .... iter 1800: loss 4.490 dyn_loss 1.418 obs_loss 307.244
# .... iter 1900: loss 4.330 dyn_loss 1.359 obs_loss 297.177
# .... iter 2000: loss 4.181 dyn_loss 1.305 obs_loss 287.542
# .... iter 2100: loss 4.040 dyn_loss 1.257 obs_loss 278.327
# .... iter 2200: loss 3.908 dyn_loss 1.213 obs_loss 269.518
# .... iter 2300: loss 3.783 dyn_loss 1.172 obs_loss 261.100
# .... iter 2400: loss 3.665 dyn_loss 1.134 obs_loss 253.060
# .... iter 2500: loss 3.553 dyn_loss 1.099 obs_loss 245.382
# .... iter 2600: loss 3.447 dyn_loss 1.066 obs_loss 238.051
# .... iter 2700: loss 3.346 dyn_loss 1.036 obs_loss 231.053
# .... iter 2800: loss 3.250 dyn_loss 1.007 obs_loss 224.375
# .... iter 2900: loss 3.159 dyn_loss 0.979 obs_loss 218.003
# .... iter 3000: loss 3.073 dyn_loss 0.954 obs_loss 211.923
# .... iter 3100: loss 2.990 dyn_loss 0.929 obs_loss 206.124
# .... iter 3200: loss 2.912 dyn_loss 0.906 obs_loss 200.593
# .... iter 3300: loss 2.837 dyn_loss 0.884 obs_loss 195.318
# .... iter 3400: loss 2.766 dyn_loss 0.863 obs_loss 190.289
# .... iter 3500: loss 2.698 dyn_loss 0.843 obs_loss 185.495
# .... iter 3600: loss 2.633 dyn_loss 0.824 obs_loss 180.925
# .... iter 3700: loss 2.572 dyn_loss 0.806 obs_loss 176.570
# .... iter 3800: loss 2.513 dyn_loss 0.789 obs_loss 172.419
# .... iter 3900: loss 2.457 dyn_loss 0.772 obs_loss 168.465
# .... iter 4000: loss 2.403 dyn_loss 0.756 obs_loss 164.698
# .... iter 4100: loss 2.352 dyn_loss 0.741 obs_loss 161.109
# .... iter 4200: loss 2.303 dyn_loss 0.726 obs_loss 157.691
# .... iter 4300: loss 2.257 dyn_loss 0.712 obs_loss 154.437
# .... iter 4400: loss 2.212 dyn_loss 0.699 obs_loss 151.338
# .... iter 4500: loss 2.170 dyn_loss 0.686 obs_loss 148.388
# .... iter 4600: loss 2.129 dyn_loss 0.674 obs_loss 145.580
# .... iter 4700: loss 2.091 dyn_loss 0.662 obs_loss 142.908
# .... iter 4800: loss 2.054 dyn_loss 0.650 obs_loss 140.364
# .... iter 4900: loss 2.019 dyn_loss 0.639 obs_loss 137.945
# .... iter 5000: loss 1.985 dyn_loss 0.629 obs_loss 135.643
# .... iter 5100: loss 1.953 dyn_loss 0.619 obs_loss 133.453
# .... iter 5200: loss 1.923 dyn_loss 0.609 obs_loss 131.371
# .... iter 5300: loss 1.894 dyn_loss 0.600 obs_loss 129.391
# .... iter 5400: loss 1.866 dyn_loss 0.591 obs_loss 127.509
# .... iter 5500: loss 1.839 dyn_loss 0.582 obs_loss 125.719
# .... iter 5600: loss 1.814 dyn_loss 0.574 obs_loss 124.018
# .... iter 5700: loss 1.790 dyn_loss 0.566 obs_loss 122.402
# .... iter 5800: loss 1.767 dyn_loss 0.558 obs_loss 120.866
# .... iter 5900: loss 1.745 dyn_loss 0.551 obs_loss 119.407
# .... iter 6000: loss 1.724 dyn_loss 0.543 obs_loss 118.021
# .... iter 6100: loss 1.703 dyn_loss 0.536 obs_loss 116.705
# .... iter 6200: loss 1.684 dyn_loss 0.530 obs_loss 115.456
# .... iter 6300: loss 1.666 dyn_loss 0.523 obs_loss 114.269
# .... iter 6400: loss 1.649 dyn_loss 0.517 obs_loss 113.144
# .... iter 6500: loss 1.632 dyn_loss 0.511 obs_loss 112.075
# .... iter 6600: loss 1.616 dyn_loss 0.505 obs_loss 111.061
# .... iter 6700: loss 1.601 dyn_loss 0.500 obs_loss 110.100
# .... iter 6800: loss 1.586 dyn_loss 0.494 obs_loss 109.188
# .... iter 6900: loss 1.572 dyn_loss 0.489 obs_loss 108.323
# .... iter 7000: loss 1.559 dyn_loss 0.484 obs_loss 107.503
# .... iter 7100: loss 1.547 dyn_loss 0.479 obs_loss 106.726
# .... iter 7200: loss 1.535 dyn_loss 0.475 obs_loss 105.990
# .... iter 7300: loss 1.523 dyn_loss 0.470 obs_loss 105.292
# .... iter 7400: loss 1.512 dyn_loss 0.466 obs_loss 104.632
# .... iter 7500: loss 1.502 dyn_loss 0.462 obs_loss 104.006
# .... iter 7600: loss 1.492 dyn_loss 0.457 obs_loss 103.414
# .... iter 7700: loss 1.482 dyn_loss 0.454 obs_loss 102.853
# .... iter 7800: loss 1.473 dyn_loss 0.450 obs_loss 102.323
# .... iter 7900: loss 1.464 dyn_loss 0.446 obs_loss 101.822
# .... iter 8000: loss 1.456 dyn_loss 0.442 obs_loss 101.348
# .... iter 8100: loss 1.448 dyn_loss 0.439 obs_loss 100.899
# .... iter 8200: loss 1.440 dyn_loss 0.436 obs_loss 100.476
# .... iter 8300: loss 1.433 dyn_loss 0.432 obs_loss 100.076
# .... iter 8400: loss 1.426 dyn_loss 0.429 obs_loss 99.698
# .... iter 8500: loss 1.420 dyn_loss 0.426 obs_loss 99.341
# .... iter 8600: loss 1.413 dyn_loss 0.423 obs_loss 99.005
# .... iter 8700: loss 1.407 dyn_loss 0.421 obs_loss 98.687
# .... iter 8800: loss 1.402 dyn_loss 0.418 obs_loss 98.388
# .... iter 8900: loss 1.396 dyn_loss 0.415 obs_loss 98.106
# .... iter 9000: loss 1.391 dyn_loss 0.413 obs_loss 97.840
# .... iter 9100: loss 1.386 dyn_loss 0.410 obs_loss 97.590
# .... iter 9200: loss 1.381 dyn_loss 0.408 obs_loss 97.355
# .... iter 9300: loss 1.377 dyn_loss 0.405 obs_loss 97.133
# .... iter 9400: loss 1.372 dyn_loss 0.403 obs_loss 96.925
# .... iter 9500: loss 1.368 dyn_loss 0.401 obs_loss 96.730
# .... iter 9600: loss 1.364 dyn_loss 0.399 obs_loss 96.546
# .... iter 9700: loss 1.360 dyn_loss 0.397 obs_loss 96.374
# .... iter 9800: loss 1.357 dyn_loss 0.395 obs_loss 96.212
# .... iter 9900: loss 1.353 dyn_loss 0.393 obs_loss 96.061
# .... iter 10000: loss 1.350 dyn_loss 0.391 obs_loss 95.919
# .... iter 10100: loss 1.347 dyn_loss 0.389 obs_loss 95.787
# .... iter 10200: loss 1.344 dyn_loss 0.387 obs_loss 95.663
# .... iter 10300: loss 1.341 dyn_loss 0.386 obs_loss 95.547
# .... iter 10400: loss 1.338 dyn_loss 0.384 obs_loss 95.439
# .... iter 10500: loss 1.336 dyn_loss 0.382 obs_loss 95.339
# .... iter 10600: loss 1.333 dyn_loss 0.381 obs_loss 95.245
# .... iter 10700: loss 1.331 dyn_loss 0.379 obs_loss 95.158
# .... iter 10800: loss 1.329 dyn_loss 0.378 obs_loss 95.078
# .... iter 10900: loss 1.326 dyn_loss 0.376 obs_loss 95.003
# .... iter 11000: loss 1.324 dyn_loss 0.375 obs_loss 94.934
# .... iter 11100: loss 1.322 dyn_loss 0.374 obs_loss 94.869
# .... iter 11200: loss 1.320 dyn_loss 0.372 obs_loss 94.810
# .... iter 11300: loss 1.319 dyn_loss 0.371 obs_loss 94.756
# .... iter 11400: loss 1.317 dyn_loss 0.370 obs_loss 94.706
# .... iter 11500: loss 1.315 dyn_loss 0.369 obs_loss 94.660
# .... iter 11600: loss 1.314 dyn_loss 0.367 obs_loss 94.618
# .... iter 11700: loss 1.312 dyn_loss 0.366 obs_loss 94.580
# .... iter 11800: loss 1.311 dyn_loss 0.365 obs_loss 94.546
# .... iter 11900: loss 1.309 dyn_loss 0.364 obs_loss 94.514
# .... iter 12000: loss 1.308 dyn_loss 0.363 obs_loss 94.486
# .... iter 12100: loss 1.307 dyn_loss 0.362 obs_loss 94.461
# .... iter 12200: loss 1.305 dyn_loss 0.361 obs_loss 94.438
# .... iter 12300: loss 1.304 dyn_loss 0.360 obs_loss 94.418
# .... iter 12400: loss 1.303 dyn_loss 0.359 obs_loss 94.400
# .... iter 12500: loss 1.302 dyn_loss 0.358 obs_loss 94.385
# .... iter 12600: loss 1.301 dyn_loss 0.357 obs_loss 94.372
# .... iter 12700: loss 1.300 dyn_loss 0.356 obs_loss 94.361
# .... iter 12800: loss 1.299 dyn_loss 0.356 obs_loss 94.352
# .... iter 12900: loss 1.298 dyn_loss 0.355 obs_loss 94.344
# .... iter 13000: loss 1.297 dyn_loss 0.354 obs_loss 94.338
# .... iter 13100: loss 1.297 dyn_loss 0.353 obs_loss 94.334
# .... iter 13200: loss 1.296 dyn_loss 0.352 obs_loss 94.331
# .... iter 13300: loss 1.295 dyn_loss 0.352 obs_loss 94.330
# .... iter 13400: loss 1.294 dyn_loss 0.351 obs_loss 94.330
# .... iter 13500: loss 1.294 dyn_loss 0.350 obs_loss 94.330
# .... iter 13600: loss 1.293 dyn_loss 0.350 obs_loss 94.333
# .... iter 13700: loss 1.292 dyn_loss 0.349 obs_loss 94.336
# .... iter 13800: loss 1.292 dyn_loss 0.348 obs_loss 94.340
# .... iter 13900: loss 1.291 dyn_loss 0.348 obs_loss 94.344
# .... iter 14000: loss 1.291 dyn_loss 0.347 obs_loss 94.350
# .... iter 14100: loss 1.290 dyn_loss 0.347 obs_loss 94.356
# .... iter 14200: loss 1.290 dyn_loss 0.346 obs_loss 94.363
# .... iter 14300: loss 1.289 dyn_loss 0.345 obs_loss 94.371
# .... iter 14400: loss 1.289 dyn_loss 0.345 obs_loss 94.379
# .... iter 14500: loss 1.288 dyn_loss 0.344 obs_loss 94.388
# .... iter 14600: loss 1.288 dyn_loss 0.344 obs_loss 94.397
# .... iter 14700: loss 1.287 dyn_loss 0.343 obs_loss 94.407
# .... iter 14800: loss 1.287 dyn_loss 0.343 obs_loss 94.417
# .... iter 14900: loss 1.287 dyn_loss 0.342 obs_loss 94.427
# .... iter 15000: loss 1.286 dyn_loss 0.342 obs_loss 94.438
# .... iter 15100: loss 1.286 dyn_loss 0.341 obs_loss 94.449
# .... iter 15200: loss 1.286 dyn_loss 0.341 obs_loss 94.460
# .... iter 15300: loss 1.285 dyn_loss 0.341 obs_loss 94.472
# .... iter 15400: loss 1.285 dyn_loss 0.340 obs_loss 94.483
# .... iter 15500: loss 1.285 dyn_loss 0.340 obs_loss 94.495
# .... iter 15600: loss 1.284 dyn_loss 0.339 obs_loss 94.507
# .... iter 15700: loss 1.284 dyn_loss 0.339 obs_loss 94.519
# .... iter 15800: loss 1.284 dyn_loss 0.338 obs_loss 94.531
# .... iter 15900: loss 1.284 dyn_loss 0.338 obs_loss 94.544
# .... iter 16000: loss 1.283 dyn_loss 0.338 obs_loss 94.556
# .... iter 16100: loss 1.283 dyn_loss 0.337 obs_loss 94.568
# .... iter 16200: loss 1.283 dyn_loss 0.337 obs_loss 94.581
# .... iter 16300: loss 1.283 dyn_loss 0.337 obs_loss 94.593
# .... iter 16400: loss 1.282 dyn_loss 0.336 obs_loss 94.605
# .... iter 16500: loss 1.282 dyn_loss 0.336 obs_loss 94.618
# .... iter 16600: loss 1.282 dyn_loss 0.336 obs_loss 94.630
# .... iter 16700: loss 1.282 dyn_loss 0.335 obs_loss 94.642
# .... iter 16800: loss 1.282 dyn_loss 0.335 obs_loss 94.655
# .... iter 16900: loss 1.281 dyn_loss 0.335 obs_loss 94.667
# .... iter 17000: loss 1.281 dyn_loss 0.335 obs_loss 94.679
# .... iter 17100: loss 1.281 dyn_loss 0.334 obs_loss 94.691
# .... iter 17200: loss 1.281 dyn_loss 0.334 obs_loss 94.702
# .... iter 17300: loss 1.281 dyn_loss 0.334 obs_loss 94.714
# .... iter 17400: loss 1.281 dyn_loss 0.333 obs_loss 94.726
# .... iter 17500: loss 1.281 dyn_loss 0.333 obs_loss 94.737
# .... iter 17600: loss 1.280 dyn_loss 0.333 obs_loss 94.749
# .... iter 17700: loss 1.280 dyn_loss 0.333 obs_loss 94.760
# .... iter 17800: loss 1.280 dyn_loss 0.332 obs_loss 94.771
# .... iter 17900: loss 1.280 dyn_loss 0.332 obs_loss 94.782
# .... iter 18000: loss 1.280 dyn_loss 0.332 obs_loss 94.793
# .... iter 18100: loss 1.280 dyn_loss 0.332 obs_loss 94.804
# .... iter 18200: loss 1.280 dyn_loss 0.332 obs_loss 94.814
# .... iter 18300: loss 1.280 dyn_loss 0.331 obs_loss 94.825
# .... iter 18400: loss 1.280 dyn_loss 0.331 obs_loss 94.835
# .... iter 18500: loss 1.279 dyn_loss 0.331 obs_loss 94.845
# .... iter 18600: loss 1.279 dyn_loss 0.331 obs_loss 94.855
# .... iter 18700: loss 1.279 dyn_loss 0.331 obs_loss 94.865
# .... iter 18800: loss 1.279 dyn_loss 0.330 obs_loss 94.875
# .... iter 18900: loss 1.279 dyn_loss 0.330 obs_loss 94.884
# .... iter 19000: loss 1.279 dyn_loss 0.330 obs_loss 94.893
# .... iter 19100: loss 1.279 dyn_loss 0.330 obs_loss 94.902
# .... iter 19200: loss 1.279 dyn_loss 0.330 obs_loss 94.912
# .... iter 19300: loss 1.279 dyn_loss 0.330 obs_loss 94.920
# .... iter 19400: loss 1.279 dyn_loss 0.329 obs_loss 94.929
# .... iter 19500: loss 1.279 dyn_loss 0.329 obs_loss 94.938
# .... iter 19600: loss 1.278 dyn_loss 0.329 obs_loss 94.946
# .... iter 19700: loss 1.278 dyn_loss 0.329 obs_loss 94.954
# .... iter 19800: loss 1.278 dyn_loss 0.329 obs_loss 94.962
# .... iter 19900: loss 1.278 dyn_loss 0.329 obs_loss 94.970

# %%
XGT  = XGT_torch.cpu().detach().numpy()[t0:t0+dT,:]
XHat = X_torch.cpu().detach().numpy()[t0:t0+dT,:]
M    = M_torch.cpu().detach().numpy()[t0:t0+dT,:]
YObs = YObs_torch.cpu().detach().numpy()[t0:t0+dT,:]

## visualization
plt.figure()
for kk in range(0,3):
  plt.subplot(1,3,kk+1)
  plt.plot(YObs[t0:t0+dT,kk],'r.')
  plt.plot(XGT[:,kk],'b-')
  plt.plot(XHat[:,kk],'m-')

# Reconstruction performance
varXGT  = np.mean( (XGT - np.mean(XGT,axis=0))**2 )
mse_All = np.mean( (XHat-XGT) **2 )
mse_I   = np.mean( (1.-M[t0:t0+dT,:]) * (XHat-XGT) **2 ) / np.mean( (1.-M[t0:t0+dT,:]) )
mse_R   = np.mean( M[t0:t0+dT,:] * (XHat-XGT) **2 ) / np.mean( M[t0:t0+dT,:] )

nmse_All = mse_All / varXGT
nmse_I   = mse_I / varXGT
nmse_R   = mse_R / varXGT

print("..... Assimilation performance")
print(".. MSE ALL.   : %.3f / %.3f"%(mse_All,nmse_All))
print(".. MSE ObsData: %.3f / %.3f"%(mse_R,nmse_R))
print(".. MSE Interp : %.3f / %.3f"%(mse_I,nmse_I))
# Out:
# ..... Assimilation performance
# .. MSE ALL.   : 2.155 / 0.033
# .. MSE ObsData: 0.407 / 0.006
# .. MSE Interp : 2.371 / 0.037
